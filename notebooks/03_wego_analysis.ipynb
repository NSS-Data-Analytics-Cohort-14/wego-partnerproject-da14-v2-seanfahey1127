# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing csv
wego = pd.read_csv(r"C:\Users\ekims\Documents\NSS\DA14\Projects\wego-partnerproject-da14-v2-ekimshaf\data\wego_tsp_assigned.csv")

# %%
wego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337365 entries, 0 to 337364
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   CALENDAR_ID                337365 non-null  int64
#  1   SERVICE_ABBR               337365 non-null  int64
#  2   ADHERENCE_ID               337365 non-null  int64
#  3   DATE                       337365 non-null  object
#  4   ROUTE_ABBR                 337365 non-null  int64
#  5   BLOCK_ABBR                 337365 non-null  int64
#  6   OPERATOR                   337365 non-null  int64
#  7   TRIP_ID                    337365 non-null  int64
#  8   OVERLOAD_ID                337365 non-null  int64
#  9   ROUTE_DIRECTION_NAME       337365 non-null  object
#  10  TIME_POINT_ABBR            337365 non-null  object
#  11  ROUTE_STOP_SEQUENCE        337365 non-null  int64
#  12  TRIP_EDGE                  337365 non-null  int64
# ...

# %%
wego.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120230101             3      93549175  2023-01-01          50
# 1    120230101             3      93549176  2023-01-01          50
# 2    120230101             3      93549177  2023-01-01          50
# 3    120230101             3      93549179  2023-01-01          50
# 4    120230101             3      93549180  2023-01-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# 0        5000      2355   332424            0          TO DOWNTOWN  ...
# 1        5000      2355   332424            0          TO DOWNTOWN  ...
# 2        5000      2355   332424            0          TO DOWNTOWN  ...
# 3        5000      2355   332425            0        FROM DOWNTOWN  ...
# 4        5000      2355   332425            0        FROM DOWNTOWN  ...
#
#   IS_RELIEF  BLOCK_STOP_ORDER  DWELL_IN_MINS  TIME_OF_DAY  SEASON IS_HOLIDAY  \
# ...

# %% [markdown]
# 1) This section begins parsing out the time and date points of TSP activation in the data into
# individual dataframes.

# %%
#Sectioning out data from before TSP activation in dataset for route in question.
# TSP began on 2/3/2025 at 12:00pm (noon)
before_tsp = wego[(wego['CALENDAR_ID'] <= 120250203) & 
(wego['TSP_PHASE_NAME'].str.contains('Pre-TSP'))]
before_tsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298732 entries, 0 to 298946
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   CALENDAR_ID                298732 non-null  int64
#  1   SERVICE_ABBR               298732 non-null  int64
#  2   ADHERENCE_ID               298732 non-null  int64
#  3   DATE                       298732 non-null  object
#  4   ROUTE_ABBR                 298732 non-null  int64
#  5   BLOCK_ABBR                 298732 non-null  int64
#  6   OPERATOR                   298732 non-null  int64
#  7   TRIP_ID                    298732 non-null  int64
#  8   OVERLOAD_ID                298732 non-null  int64
#  9   ROUTE_DIRECTION_NAME       298732 non-null  object
#  10  TIME_POINT_ABBR            298732 non-null  object
#  11  ROUTE_STOP_SEQUENCE        298732 non-null  int64
#  12  TRIP_EDGE                  298732 non-null  int64
# ...

# %%
before_tsp
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0         120230101             3      93549175  2023-01-01          50
# 1         120230101             3      93549176  2023-01-01          50
# 2         120230101             3      93549177  2023-01-01          50
# 3         120230101             3      93549179  2023-01-01          50
# 4         120230101             3      93549180  2023-01-01          50
# ...             ...           ...           ...         ...         ...
# 298942    120250203             1     117340535  2025-02-03          50
# 298943    120250203             1     117340536  2025-02-03          50
# 298944    120250203             1     117340541  2025-02-03          50
# 298945    120250203             1     117340542  2025-02-03          50
# 298946    120250203             1     117340543  2025-02-03          50
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
##filtering dates that are included in unconditional TSP, Feb 3rd - Feb 10th, 2025 11:59am
tsp_uncon_feb = wego[(wego['CALENDAR_ID'] >= 120250203) & 
(wego['CALENDAR_ID'] <= 120250210) &
(wego['TSP_PHASE_NAME'].str.contains('TSP Unconditional 1'))]
tsp_uncon_feb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2830 entries, 298541 to 301758
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CALENDAR_ID                2830 non-null   int64
#  1   SERVICE_ABBR               2830 non-null   int64
#  2   ADHERENCE_ID               2830 non-null   int64
#  3   DATE                       2830 non-null   object
#  4   ROUTE_ABBR                 2830 non-null   int64
#  5   BLOCK_ABBR                 2830 non-null   int64
#  6   OPERATOR                   2830 non-null   int64
#  7   TRIP_ID                    2830 non-null   int64
#  8   OVERLOAD_ID                2830 non-null   int64
#  9   ROUTE_DIRECTION_NAME       2830 non-null   object
#  10  TIME_POINT_ABBR            2830 non-null   object
#  11  ROUTE_STOP_SEQUENCE        2830 non-null   int64
#  12  TRIP_EDGE                  2830 non-null   int64
# ...

# %%
tsp_uncon_feb
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 298541    120250203             1     117339007  2025-02-03          50
# 298570    120250203             1     117339883  2025-02-03          50
# 298571    120250203             1     117339884  2025-02-03          50
# 298572    120250203             1     117339885  2025-02-03          50
# 298573    120250203             1     117339887  2025-02-03          50
# ...             ...           ...           ...         ...         ...
# 301754    120250210             1     117582258  2025-02-10          50
# 301755    120250210             1     117582259  2025-02-10          50
# 301756    120250210             1     117582264  2025-02-10          50
# 301757    120250210             1     117582265  2025-02-10          50
# 301758    120250210             1     117582266  2025-02-10          50
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
##filtering dates that are included in conditional TSP, Feb 10th - Apr 28, 2025
tsp_cond_feb = wego[(wego['CALENDAR_ID'] >= 120250210) & 
(wego['CALENDAR_ID'] <= 120250428) &
(wego['TSP_PHASE_NAME'].str.contains('TSP Schedule-Conditional'))]
tsp_cond_feb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29800 entries, 301399 to 331579
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CALENDAR_ID                29800 non-null  int64
#  1   SERVICE_ABBR               29800 non-null  int64
#  2   ADHERENCE_ID               29800 non-null  int64
#  3   DATE                       29800 non-null  object
#  4   ROUTE_ABBR                 29800 non-null  int64
#  5   BLOCK_ABBR                 29800 non-null  int64
#  6   OPERATOR                   29800 non-null  int64
#  7   TRIP_ID                    29800 non-null  int64
#  8   OVERLOAD_ID                29800 non-null  int64
#  9   ROUTE_DIRECTION_NAME       29800 non-null  object
#  10  TIME_POINT_ABBR            29800 non-null  object
#  11  ROUTE_STOP_SEQUENCE        29800 non-null  int64
#  12  TRIP_EDGE                  29800 non-null  int64
# ...

# %%
tsp_cond_feb
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 301399    120250210             1     117581594  2025-02-10          50
# 301400    120250210             1     117581595  2025-02-10          50
# 301401    120250210             1     117581596  2025-02-10          50
# 301402    120250210             1     117581598  2025-02-10          50
# 301403    120250210             1     117581599  2025-02-10          50
# ...             ...           ...           ...         ...         ...
# 331575    120250428             1     119086565  2025-04-28          50
# 331576    120250428             1     119086566  2025-04-28          50
# 331577    120250428             1     119086571  2025-04-28          50
# 331578    120250428             1     119086572  2025-04-28          50
# 331579    120250428             1     119086573  2025-04-28          50
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
#filtering dates with TSP off between Apr 28th and May 5th
tsp_off_apr = wego[(wego['CALENDAR_ID'] >= 120250428) & 
(wego['CALENDAR_ID'] <= 120250505) &
(wego['TSP_PHASE_NAME'].str.contains('TSP Off'))]
tsp_off_apr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2853 entries, 331199 to 334429
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CALENDAR_ID                2853 non-null   int64
#  1   SERVICE_ABBR               2853 non-null   int64
#  2   ADHERENCE_ID               2853 non-null   int64
#  3   DATE                       2853 non-null   object
#  4   ROUTE_ABBR                 2853 non-null   int64
#  5   BLOCK_ABBR                 2853 non-null   int64
#  6   OPERATOR                   2853 non-null   int64
#  7   TRIP_ID                    2853 non-null   int64
#  8   OVERLOAD_ID                2853 non-null   int64
#  9   ROUTE_DIRECTION_NAME       2853 non-null   object
#  10  TIME_POINT_ABBR            2853 non-null   object
#  11  ROUTE_STOP_SEQUENCE        2853 non-null   int64
#  12  TRIP_EDGE                  2853 non-null   int64
# ...

# %%
tsp_off_apr
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 331199    120250428             1     119085913  2025-04-28          50
# 331200    120250428             1     119085914  2025-04-28          50
# 331201    120250428             1     119085915  2025-04-28          50
# 331202    120250428             1     119085917  2025-04-28          50
# 331203    120250428             1     119085918  2025-04-28          50
# ...             ...           ...           ...         ...         ...
# 334425    120250505             1     119328666  2025-05-05          50
# 334426    120250505             1     119328667  2025-05-05          50
# 334427    120250505             1     119328672  2025-05-05          50
# 334428    120250505             1     119328673  2025-05-05          50
# 334429    120250505             1     119328674  2025-05-05          50
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
#Filtering dates for headway priority condition for TSP beginning May 12th
tsp_cond_may = wego[(wego['CALENDAR_ID'] >= 120250512) &
(wego['TSP_PHASE_NAME'].str.contains('TSP Headway-Conditional'))]
tsp_cond_may.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 266 entries, 336911 to 337364
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CALENDAR_ID                266 non-null    int64
#  1   SERVICE_ABBR               266 non-null    int64
#  2   ADHERENCE_ID               266 non-null    int64
#  3   DATE                       266 non-null    object
#  4   ROUTE_ABBR                 266 non-null    int64
#  5   BLOCK_ABBR                 266 non-null    int64
#  6   OPERATOR                   266 non-null    int64
#  7   TRIP_ID                    266 non-null    int64
#  8   OVERLOAD_ID                266 non-null    int64
#  9   ROUTE_DIRECTION_NAME       266 non-null    object
#  10  TIME_POINT_ABBR            266 non-null    object
#  11  ROUTE_STOP_SEQUENCE        266 non-null    int64
#  12  TRIP_EDGE                  266 non-null    int64
# ...

# %%
tsp_cond_may
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 336911    120250512             1     119523125  2025-05-12          50
# 336940    120250512             1     119524028  2025-05-12          50
# 336941    120250512             1     119524029  2025-05-12          50
# 336942    120250512             1     119524030  2025-05-12          50
# 336943    120250512             1     119524032  2025-05-12          50
# ...             ...           ...           ...         ...         ...
# 337360    120250512             1     119524764  2025-05-12          50
# 337361    120250512             1     119524765  2025-05-12          50
# 337362    120250512             1     119524766  2025-05-12          50
# 337363    120250512             1     119524767  2025-05-12          50
# 337364    120250512             1     119531770  2025-05-12          50
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %% [markdown]
# 2. Data has been sectioned out into dataframes for each timepoint:
#
# Dataframe names:
#
# before_tsp
# tsp_uncon_feb
# tsp_cond_feb
# tsp_off_apr
# tsp_cond_may
